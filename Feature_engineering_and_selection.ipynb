# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
pd.set_option('display.max_rows',None)

# %%
train=pd.read_csv(r'/content/train.csv')
#printing top 5 rows
train.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# ## missing values

# %%
missing_features=[i for i in train.columns if train[i].isnull().sum()>0]
for i in missing_features:
  print(i,np.round(train[i].isnull().mean(),4),"% values")
# Out:
# LotFrontage 0.1774 % values
# Alley 0.9377 % values
# MasVnrType 0.0055 % values
# MasVnrArea 0.0055 % values
# BsmtQual 0.0253 % values
# BsmtCond 0.0253 % values
# BsmtExposure 0.026 % values
# BsmtFinType1 0.0253 % values
# BsmtFinType2 0.026 % values
# Electrical 0.0007 % values
# FireplaceQu 0.4726 % values
# GarageType 0.0555 % values
# GarageYrBlt 0.0555 % values
# GarageFinish 0.0555 % values
# GarageQual 0.0555 % values
# GarageCond 0.0555 % values
# PoolQC 0.9952 % values
# Fence 0.8075 % values
# MiscFeature 0.963 % values

# %%
for i in missing_features:
  if train[i].dtypes=='object':
    train[i]=train[i].fillna("missing_value")
  else:
    train[i]=train[i].fillna(train[i].median())

# %%
train.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# Alley            0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# ...

# %%
## Temporal Variables (Date Time Variables)

for feature in ['YearBuilt','YearRemodAdd','GarageYrBlt']:
       
    train[feature]=train['YrSold']-train[feature]

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street          Alley  \
# 0   1          60       RL         65.0     8450   Pave  missing_value
# 1   2          20       RL         80.0     9600   Pave  missing_value
# 2   3          60       RL         68.0    11250   Pave  missing_value
# 3   4          70       RL         60.0     9550   Pave  missing_value
# 4   5          60       RL         84.0    14260   Pave  missing_value
#
#   LotShape LandContour Utilities  ... PoolArea         PoolQC          Fence  \
# 0      Reg         Lvl    AllPub  ...        0  missing_value  missing_value
# 1      Reg         Lvl    AllPub  ...        0  missing_value  missing_value
# 2      IR1         Lvl    AllPub  ...        0  missing_value  missing_value
# 3      IR1         Lvl    AllPub  ...        0  missing_value  missing_value
# 4      IR1         Lvl    AllPub  ...        0  missing_value  missing_value
#
#      MiscFeature MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train[['YearBuilt','YearRemodAdd','GarageYrBlt']].head()
# Out:
#    YearBuilt  YearRemodAdd  GarageYrBlt
# 0          5             5          5.0
# 1         31            31         31.0
# 2          7             6          7.0
# 3         91            36          8.0
# 4          8             8          8.0

# %% [markdown]
# ##numerical values
# - numerical data is skewed so perform log normal distribution

# %%
import numpy as np
num_features=['LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea', 'SalePrice']

for feature in num_features:
    train[feature]=np.log(train[feature])

# %%
train.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage   LotArea Street          Alley  \
# 0   1          60       RL     4.174387  9.041922   Pave  missing_value
# 1   2          20       RL     4.382027  9.169518   Pave  missing_value
# 2   3          60       RL     4.219508  9.328123   Pave  missing_value
# 3   4          70       RL     4.094345  9.164296   Pave  missing_value
# 4   5          60       RL     4.430817  9.565214   Pave  missing_value
#
#   LotShape LandContour Utilities  ... PoolArea         PoolQC          Fence  \
# 0      Reg         Lvl    AllPub  ...        0  missing_value  missing_value
# 1      Reg         Lvl    AllPub  ...        0  missing_value  missing_value
# 2      IR1         Lvl    AllPub  ...        0  missing_value  missing_value
# 3      IR1         Lvl    AllPub  ...        0  missing_value  missing_value
# 4      IR1         Lvl    AllPub  ...        0  missing_value  missing_value
#
# ...

# %% [markdown]
# ## categorical values

# %%
for i in train.columns:
  print(i,len(train[i].unique()))
# Out:
# Id 1460
# MSSubClass 15
# MSZoning 5
# LotFrontage 110
# LotArea 1073
# Street 2
# Alley 3
# LotShape 4
# LandContour 4
# Utilities 2
# LotConfig 5
# LandSlope 3
# Neighborhood 25
# Condition1 9
# Condition2 8
# BldgType 5
# HouseStyle 8
# OverallQual 10
# OverallCond 9
# YearBuilt 122
# YearRemodAdd 62
# RoofStyle 6
# RoofMatl 8
# Exterior1st 15
# Exterior2nd 16
# MasVnrType 5
# MasVnrArea 327
# ExterQual 4
# ExterCond 5
# Foundation 6
# BsmtQual 5
# BsmtCond 5
# BsmtExposure 5
# BsmtFinType1 7
# BsmtFinSF1 637
# BsmtFinType2 7
# BsmtFinSF2 144
# BsmtUnfSF 780
# TotalBsmtSF 721
# Heating 6
# HeatingQC 5
# CentralAir 2
# Electrical 6
# 1stFlrSF 753
# 2ndFlrSF 417
# LowQualFinSF 24
# GrLivArea 861
# BsmtFullBath 4
# BsmtHalfBath 3
# FullBath 4
# HalfBath 3
# BedroomAbvGr 8
# KitchenAbvGr 4
# KitchenQual 4
# TotRmsAbvGrd 12
# Functional 7
# Fireplaces 4
# FireplaceQu 6
# GarageType 7
# GarageYrBlt 101
# GarageFinish 4
# GarageCars 5
# GarageArea 441
# GarageQual 6
# GarageCond 6
# ...

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage   LotArea Street          Alley  \
# 0   1          60       RL     4.174387  9.041922   Pave  missing_value
# 1   2          20       RL     4.382027  9.169518   Pave  missing_value
# 2   3          60       RL     4.219508  9.328123   Pave  missing_value
# 3   4          70       RL     4.094345  9.164296   Pave  missing_value
# 4   5          60       RL     4.430817  9.565214   Pave  missing_value
#
#   LotShape LandContour Utilities  ... PoolArea         PoolQC          Fence  \
# 0      Reg         Lvl    AllPub  ...        0  missing_value  missing_value
# 1      Reg         Lvl    AllPub  ...        0  missing_value  missing_value
# 2      IR1         Lvl    AllPub  ...        0  missing_value  missing_value
# 3      IR1         Lvl    AllPub  ...        0  missing_value  missing_value
# 4      IR1         Lvl    AllPub  ...        0  missing_value  missing_value
#
# ...

# %% [markdown]
# ##Handling Rare Categorical Feature

# %%
categorical_features=train.select_dtypes(include=['object'])

# %%
for feature in categorical_features:
    temp=train.groupby(feature)['SalePrice'].count()/len(train)
    temp_df=temp[temp>0.01].index
    train[feature]=np.where(train[feature].isin(temp_df),train[feature],'Rare_var')

# %%
for feature in categorical_features:
    labels_ordered=train.groupby([feature])['SalePrice'].mean().sort_values().index
    labels_ordered={k:i for i,k in enumerate(labels_ordered,0)}
    train[feature]=train[feature].map(labels_ordered)

# %%
train.head(5)
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# 0   1          60         3     4.174387  9.041922       1      2         0
# 1   2          20         3     4.382027  9.169518       1      2         0
# 2   3          60         3     4.219508  9.328123       1      2         1
# 3   4          70         3     4.094345  9.164296       1      2         1
# 4   5          60         3     4.430817  9.565214       1      2         1
#
#    LandContour  Utilities  ...  PoolArea  PoolQC  Fence  MiscFeature  MiscVal  \
# 0            1          1  ...         0       0      4            2        0
# 1            1          1  ...         0       0      4            2        0
# 2            1          1  ...         0       0      4            2        0
# 3            1          1  ...         0       0      4            2        0
# 4            1          1  ...         0       0      4            2        0
#
# ...

# %% [markdown]
# # Feature Engineering

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

# %%
X=train.drop(['Id','SalePrice'],axis=1)
scaler.fit(X)
X_scaled=scaler.transform(X)

# %%
y=train['SalePrice']

# %%
print(X.shape,y.shape)
# Out:
# (1460, 79) (1460,)

# %% [markdown]
# - feature selection we will apply lasso model

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV,train_test_split,KFold
from sklearn.feature_selection import SelectFromModel

# %%
feature_sel_model = SelectFromModel(Lasso(alpha=0.005, random_state=0))
feature_sel_model.fit(X_scaled, y)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.005, random_state=0))

# %%
feature_sel_model.get_support()
# Out:
# array([ True,  True, False, False, False, False, False, False, False,
#        False, False,  True, False, False, False, False,  True, False,
#        False,  True,  True, False, False, False, False, False, False,
#        False, False,  True, False,  True, False, False, False, False,
#        False, False, False,  True,  True, False,  True, False, False,
#         True,  True, False, False, False, False, False,  True, False,
#        False,  True,  True,  True, False,  True,  True, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True])

# %%
selected_feat = X.columns[(feature_sel_model.get_support())]
len(selected_feat)
# Out:
# 21

# %%
X=X[selected_feat]

# %%
X.head()
# Out:
#    MSSubClass  MSZoning  Neighborhood  OverallQual  YearRemodAdd  RoofStyle  \
# 0          60         3            14            7             5          0
# 1          20         3            11            6            31          0
# 2          60         3            14            7             6          0
# 3          70         3            16            7            36          0
# 4          60         3            22            8             8          0
#
#    BsmtQual  BsmtExposure  HeatingQC  CentralAir  ...  GrLivArea  \
# 0         3             1          4           1  ...   7.444249
# 1         3             4          4           1  ...   7.140453
# 2         3             2          4           1  ...   7.487734
# 3         2             1          3           1  ...   7.448334
# 4         3             3          4           1  ...   7.695303
#
#    BsmtFullBath  KitchenQual  Fireplaces  FireplaceQu  GarageType  \
# ...

# %%
X.shape
# Out:
# (1460, 21)

# %%
X.to_csv("X_train.csv",index=False)
y.to_csv("Y_train.csv",index=False)
